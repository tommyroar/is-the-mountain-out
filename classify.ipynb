# %% [markdown]
# # 🏔️ Mountain Classifier
# Use this notebook to quickly label captured webcam data. Labels are saved to `data/labels.yaml` which can be used by the training scheduler.

# %%
# %load_ext autoreload
# %autoreload 2
from collect.notebook_helpers import MountainClassifier, get_data_root

data_root = get_data_root()
classifier = MountainClassifier(data_root=data_root)
classifier.start()

# %% [markdown]
# ### Usage Tips:
# - **MOUNTAIN IS OUT (1)**: Label the image as visible (Class 1).
# - **NOT OUT (0)**: Label the image as obscured or not visible (Class 0).
# - **SKIP**: Move to the next image without saving a label for this one.
