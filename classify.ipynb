# %% [markdown]
# # 🏔️ Batch Mountain Classifier
# Use this notebook to bulk-label images. Labels are saved directly to `labels.yaml`.

# %%
import os, sys
from pathlib import Path

data_root = os.environ.get("MOUNTAIN_DATA_ROOT", "data")

# %load_ext autoreload
# %autoreload 2
from collect.notebook_helpers import MountainClassifier

print(f"Classifying data in: {data_root}")
classifier = MountainClassifier(data_root=data_root)
classifier.start()
# Out:
# Classifying data in: /Users/tommydoerr/dev/is-the-mountain-out/data
# Scanning /Users/tommydoerr/dev/is-the-mountain-out/data for images...
# Found 1279 total images.
# Resuming from saved index: 564
# ...
